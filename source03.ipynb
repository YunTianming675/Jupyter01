# %%
import numpy

# %%
tab = list()
for i in range(64):
    tab.append(hex(int(numpy.sin(i*1.4*numpy.pi/180)*128+128)))
print(tab)
# Out:
# ['0x80', '0x83', '0x86', '0x89', '0x8c', '0x8f', '0x92', '0x95', '0x98', '0x9b', '0x9e', '0xa1', '0xa4', '0xa7', '0xaa', '0xad', '0xb0', '0xb3', '0xb6', '0xb9', '0xbc', '0xbe', '0xc1', '0xc4', '0xc6', '0xc9', '0xcb', '0xce', '0xd0', '0xd3', '0xd5', '0xd7', '0xda', '0xdc', '0xde', '0xe0', '0xe2', '0xe4', '0xe6', '0xe8', '0xea', '0xeb', '0xed', '0xef', '0xf0', '0xf2', '0xf3', '0xf4', '0xf5', '0xf7', '0xf8', '0xf9', '0xfa', '0xfb', '0xfb', '0xfc', '0xfd', '0xfd', '0xfe', '0xfe', '0xff', '0xff', '0xff', '0xff']

# %%
tab.clear()
for i in range(64):
    tab.append(hex(int(128-numpy.sin(i*1.4*numpy.pi/180)*128)))
print(tab)
# Out:
# ['0x80', '0x7c', '0x79', '0x76', '0x73', '0x70', '0x6d', '0x6a', '0x67', '0x64', '0x61', '0x5e', '0x5b', '0x58', '0x55', '0x52', '0x4f', '0x4c', '0x49', '0x46', '0x43', '0x41', '0x3e', '0x3b', '0x39', '0x36', '0x34', '0x31', '0x2f', '0x2c', '0x2a', '0x28', '0x25', '0x23', '0x21', '0x1f', '0x1d', '0x1b', '0x19', '0x17', '0x15', '0x14', '0x12', '0x10', '0xf', '0xd', '0xc', '0xb', '0xa', '0x8', '0x7', '0x6', '0x5', '0x4', '0x4', '0x3', '0x2', '0x2', '0x1', '0x1', '0x0', '0x0', '0x0', '0x0']
